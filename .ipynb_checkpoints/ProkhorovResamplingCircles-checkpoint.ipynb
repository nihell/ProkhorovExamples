# %%
# %matplotlib notebook
import gudhi as gd
import matplotlib.pyplot as plt
import numpy as np
from igraph import *
from scipy import sparse
import ripser
import cechmate as cm
import persim
from persim import plot_diagrams

# %%
#set-up
np.random.seed(0)
n_iter = 100
alpha = cm.Alpha()

# First, sample points from two circles

# First point cloud has no noise
N1 = 100
t1 = np.linspace(0, 2*np.pi, N1+1)[0:N1]
Xs = [None]*2
for i in range(0,len(Xs)):
    Xs[i] = np.zeros((N1, 2))
    Xs[i][:, 0] = 1*np.cos(t1)+4*i
    Xs[i][:, 1] = 1*np.sin(t1)


X = np.concatenate(Xs)

filtration = alpha.build(X)
Ix = alpha.diagrams(filtration)[1]


r_vals1 = [None] * n_iter

# Second point cloud has a lot of noisy points

for i in range(0,n_iter):
    Y = X + 0.2*np.random.randn(N1*2, 2)
    filtration = alpha.build(Y)
    Iy = alpha.diagrams(filtration)[1]
    n_points1=len(Ix)+len(Iy)
    #compute the D_{X,Y} values
    d_vals1 = np.linspace(0,n_points1,n_points1+1)
    r_vals1[i] = [gd.prokhorov_distance(Ix, Iy, np.array([r])) for r in d_vals1]
    
# Now, sample points from four circles

# First point cloud has no noise
N2 = 100
t2 = np.linspace(0, 2*np.pi, N2+1)[0:N2]
Ws = [None]*4
for i in range(0,len(Ws)):
    Ws[i] = np.zeros((N2, 2))
    Ws[i][:, 0] = 1*np.cos(t2)+4*i
    Ws[i][:, 1] = 1*np.sin(t2)


W = np.concatenate(Ws)

filtration = alpha.build(W)
Iw = alpha.diagrams(filtration)[1]


r_vals2 = [None] * n_iter

# Second point cloud has a lot of noisy points

for i in range(0,n_iter):
    Z = W + 0.2*np.random.randn(N2*4, 2)
    filtration = alpha.build(Z)
    Iz = alpha.diagrams(filtration)[1]
    n_points2=len(Iw)+len(Iz)
    #compute the D_{W,Z} values
    d_vals2 = np.linspace(0,n_points2,n_points2+1)
    r_vals2[i] = [gd.prokhorov_distance(Iw, Iz, np.array([r])) for r in d_vals2]
# Out:
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00324)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0729)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.00922)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00127)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000681)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0885)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00137)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000703)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0871)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0112)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00146)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000754)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0878)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0112)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00144)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000638)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.091)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0123)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00189)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00069)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0939)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0115)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00141)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000897)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0925)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0157)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00164)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0007)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0878)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.011)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00137)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00066)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0893)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0111)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00152)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000687)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0885)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00147)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000693)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0885)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00147)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000719)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0873)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0015)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000668)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0881)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0113)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00142)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000731)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0887)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0113)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000839)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0919)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00143)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000687)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0888)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000704)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.088)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00143)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000701)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0893)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00148)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000675)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0881)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0113)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00146)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000697)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0888)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00145)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000696)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0881)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0115)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00145)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000667)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0896)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0116)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00148)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000742)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0878)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0113)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00146)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000707)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0862)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00145)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000691)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0889)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0114)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00148)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000673)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0898)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0116)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00153)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000711)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0895)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0116)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000713)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.091)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0118)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00154)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000711)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.088)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00153)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000743)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0863)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00154)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000682)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0914)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00152)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000706)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.09)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0118)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00152)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000751)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0877)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00151)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000793)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0862)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00073)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0871)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00151)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000814)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0876)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000662)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0879)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000725)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0895)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00158)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000746)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0907)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00167)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000807)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.09)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000728)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0909)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00158)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000698)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0896)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0128)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00153)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00073)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0863)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0118)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0015)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000697)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0899)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0118)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00154)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000727)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0871)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00152)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000691)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0873)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00153)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000748)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0877)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00151)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000716)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0874)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0118)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00152)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000662)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.088)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00159)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000731)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0899)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000691)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0863)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00158)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000714)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0873)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00148)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000754)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0851)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0015)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000696)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0843)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0116)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000683)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0865)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0116)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00148)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000726)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0861)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0116)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000708)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0865)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0116)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00158)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000683)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0873)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00152)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00067)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0865)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000725)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0853)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0115)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00151)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00072)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0874)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00149)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000708)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0885)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0117)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000712)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0885)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00159)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000813)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0874)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000767)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0941)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00165)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000767)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0894)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000793)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0879)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000778)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0876)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00154)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000827)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0869)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000767)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0888)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0129)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00166)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000758)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0878)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00158)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000733)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0891)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0008)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0885)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00071)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0876)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000757)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0878)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00157)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000799)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0873)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00159)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000809)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0872)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0016)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000836)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0873)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00157)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000784)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.087)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00154)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000785)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0874)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0123)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000781)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0873)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00157)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000811)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0886)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000816)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0888)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000752)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.088)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00157)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00076)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0881)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0123)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00158)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000784)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0867)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000795)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0877)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0125)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00157)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000804)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0861)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000762)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0879)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00158)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000762)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0861)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000717)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0874)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0123)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0015)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00079)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0873)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000775)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0879)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.012)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0016)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000775)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0876)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00157)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000738)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0885)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0123)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000747)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0886)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00154)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000718)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0894)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00172)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000697)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0886)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00156)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000674)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0868)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0119)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00176)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000729)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0889)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0122)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00155)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.000689)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.0885)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0121)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00157)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00304)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.153)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0218)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00321)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.183)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0249)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00309)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00134)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.184)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0249)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00315)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00132)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.18)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0244)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00306)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00134)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.18)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0246)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00313)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00135)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.184)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0258)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00345)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00125)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.177)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0242)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00311)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00136)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.199)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0423)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00367)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00134)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.183)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0252)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00323)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00127)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.217)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0249)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00315)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00134)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0254)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00317)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00133)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.2)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0278)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00352)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00135)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.184)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0252)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00312)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00128)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.183)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0255)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00313)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00133)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.183)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0253)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00319)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.183)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0253)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00337)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00129)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.18)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0252)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00315)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00133)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0247)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00313)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00137)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0248)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00313)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0013)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0251)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00316)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00127)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.181)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0245)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00314)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00136)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.185)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0253)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00318)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00142)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.185)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0256)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00317)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00136)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.19)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0253)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00318)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.193)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0256)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0032)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00129)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.191)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0262)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00311)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00141)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.186)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0252)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00342)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.186)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0248)
# Computing persistence pairs...
# ...
# Finished computing persistence pairs (Elapsed Time 0.00339)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0014)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.187)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0259)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00335)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0013)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.186)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0249)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00317)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0013)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0253)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00342)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00126)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0254)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00319)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00133)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.183)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0254)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0033)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.186)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0253)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00323)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00139)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.185)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0254)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00318)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.184)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0264)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00325)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00135)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.187)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0251)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00324)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0013)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.185)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.311)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00593)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00133)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.185)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0248)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00358)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00135)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.189)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0263)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00332)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00127)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.188)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0259)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00313)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00126)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0249)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00343)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.025)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00326)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00125)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.179)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0246)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00311)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00128)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0263)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00375)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00128)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.18)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0247)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00323)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00134)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0292)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0032)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.187)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.025)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00325)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00163)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.187)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0256)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00397)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00139)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.192)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0274)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00326)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00135)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.19)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0258)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0032)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00128)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.182)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.025)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00319)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00128)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.185)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0259)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00315)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0013)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.181)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0242)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00316)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00131)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.184)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0253)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00318)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00139)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.183)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0256)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00316)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00137)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.186)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0253)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0032)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00162)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.205)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0278)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00348)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00143)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.198)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0282)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00338)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00142)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.196)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0273)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0035)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00137)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.195)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0282)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00327)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00139)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.191)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0279)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00327)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00145)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.19)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0261)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00337)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00144)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.193)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0267)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00344)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00133)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.191)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0271)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00328)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.0014)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.189)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0258)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00329)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00146)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.19)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0264)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00333)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00134)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.186)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0261)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00316)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00134)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.19)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0263)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00361)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00137)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.188)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0261)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.0034)
# Doing spatial.Delaunay triangulation...
# Finished spatial.Delaunay triangulation (Elapsed Time 0.00137)
# Building alpha filtration...
# Finished building alpha filtration (Elapsed Time 0.189)
# Constructing boundary matrix...
# Finished constructing boundary matrix (Elapsed Time 0.0275)
# Computing persistence pairs...
# Finished computing persistence pairs (Elapsed Time 0.00325)

# %%
l1 = min([len(ar) for ar in r_vals1])
r_mean1 = [np.mean([r_vals1[i][j] for i in range(0,len(r_vals1))]) for j in range(0,l1)]
r_max1 = [np.max([r_vals1[i][j] for i in range(0,len(r_vals1))]) for j in range(0,l1)]
r_min1 = [np.min([r_vals1[i][j] for i in range(0,len(r_vals1))]) for j in range(0,l1)]
r_std1 = [np.std([r_vals1[i][j] for i in range(0,len(r_vals1))]) for j in range(0,l1)]

l2 = min([len(ar) for ar in r_vals2])
r_mean2 = [np.mean([r_vals2[i][j] for i in range(0,len(r_vals2))]) for j in range(0,l2)]
r_max2 = [np.max([r_vals2[i][j] for i in range(0,len(r_vals2))]) for j in range(0,l2)]
r_min2 = [np.min([r_vals2[i][j] for i in range(0,len(r_vals2))]) for j in range(0,l2)]
r_std2 = [np.std([r_vals2[i][j] for i in range(0,len(r_vals2))]) for j in range(0,l2)]

fig = plt.figure(figsize = (10,5))
plt.subplot(121)
for i in range(1,l1):
    plt.plot((r_min1[i],r_min1[i-1]),(i, i), c='k', ls = ':', label='min $D_{X,Y}$')
    plt.plot((r_mean1[i-1]-r_std1[i-1],r_mean1[i-1]+r_std1[i-1]),(i, i), c='orange', label='$\sigma$')
    plt.plot((r_mean1[i]-r_std1[i],r_mean1[i]+r_std1[i]),(i, i), c='orange', label='$\sigma$')
    plt.plot((r_mean1[i],r_mean1[i-1]),(i, i), c='c', linewidth = 3, label='mean $D_{X,Y}$')
    plt.plot((r_max1[i],r_max1[i-1]),(i, i), c='k', ls = ':', label='max $D_{X,Y}$')
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc="upper right")

plt.subplot(122)
for i in range(1,l2):
    plt.plot((r_min2[i],r_min2[i-1]),(i, i), c='k', ls = ':', label='min $D_{W,Z}$')
    plt.plot((r_mean2[i-1]-r_std2[i-1],r_mean2[i-1]+r_std2[i-1]),(i, i), c='orange', label='$\sigma$')
    plt.plot((r_mean2[i]-r_std2[i],r_mean2[i]+r_std2[i]),(i, i), c='orange', label='$\sigma$')
    plt.plot((r_mean2[i],r_mean2[i-1]),(i, i), c='c', linewidth = 3, label='mean $D_{W,Z}$')
    plt.plot((r_max2[i],r_max2[i-1]),(i, i), c='k', ls = ':', label='max $D_{W,Z}$')
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc="upper right")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def D(r_vals, t):
    return np.min(np.where(np.array(r_vals)<=t))

# %%
fig = plt.figure(figsize = (10,5))
ts = np.linspace(0,0.5,100)
Dmean = np.array([np.mean([D(r,t) for r in r_vals1]) for t in ts])
Dstd = np.array([np.std([D(r,t) for r in r_vals1]) for t in ts])
plt.errorbar(ts,Dmean,Dstd, linestyle='None', marker='o', ms = 2, label = "$D_{X,Y}$")

Dmean = np.array([np.mean([D(r,t) for r in r_vals2]) for t in ts])
Dstd = np.array([np.std([D(r,t) for r in r_vals2]) for t in ts])
plt.errorbar(ts,Dmean,Dstd, linestyle='None', marker='o', ms = 2, label = "$D_{W,Z}$")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc="upper right")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
persim.plot_diagrams([Ix,Iy])
plt.subplot(122)
persim.plot_diagrams([Iw,Iz])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,9))
plt.subplot(211)
plt.scatter(X[:,0],X[:,1])
plt.scatter(Y[:,0],Y[:,1])
plt.subplot(212)
plt.scatter(W[:,0],W[:,1])
plt.scatter(Z[:,0],Z[:,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
